# %%
# !git clone https://"username":"password"@github.com/Dia-Bete/BeteQA.git
# Out:
# Cloning into 'BeteQA'...
# remote: Enumerating objects: 300, done.
# remote: Counting objects: 100% (300/300), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 300 (delta 170), reused 250 (delta 129), pack-reused 0
# Receiving objects: 100% (300/300), 1.87 MiB | 1.33 MiB/s, done.
# Resolving deltas: 100% (170/170), done.

# %%
import numpy as np
from sklearn.metrics import average_precision_score
import os
os.chdir('BeteQA')

import nltk
nltk.download('stopwords')
nltk.download('punkt')

# !pip3 install transformers
# !pip3 install tensorflow_text
# !wget https://tfhub.dev/google/universal-sentence-encoder-multilingual-large/3?tf-hub-format=compressed
# !mv /content/BeteQA/3?tf-hub-format=compressed muse.tar.gz
# !mkdir muse
# !tar -xvf muse.tar.gz -C muse
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/tcastrof/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/tcastrof/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import csv

testset = {}
with open('QA/testset.csv') as f:
  reader = csv.reader(f, delimiter=',', quotechar='\"')
  for row in list(reader)[1:]:
    q1, q2, answer, label, _ = row
    if q1.strip() not in testset:
      testset[q1] = []
    testset[q1].append({
        'question': q2.strip(),
        'answer': answer,
        'label': label
    })

corpora_path = [
        'QA/adalberto/qa_pt.json',
        'QA/diabetes_action/qa_pt.json',
        'QA/diabetesbr/qa_pt.json',
        'QA/eatingwell/qa_pt.json',
        'QA/medicine/qa_pt.json'
    ]

# %% [markdown]
# ## BM25

# %%
from models.bm25 import BM25QA

model = BM25QA(corpora_path)

bm25 = []
MAP = []
for q1 in testset:
    y_real, y_pred = [], []
    size = len(testset[q1])
    for i, row in enumerate(testset[q1]):
        q2 = row['question']
        label = row['label']

        score = model.score_pair(q1, q2)

        y_real.append(1 if label in ['S', 'R'] else 0)
        y_pred.append(score)
        
        bm25.append({
            'qid': i+1,
            'class': 2 if label == 'S' else 1 if label == 'R' else 0,
            'score': score,
            'q': q1,
            'candidate': q2
        })
        
        if len(list(set(y_real))) > 1:
            MAP.append(average_precision_score(y_real, y_pred))
print("BM25 Score:", round(np.mean(MAP), 2))
# Out:
# BM25 Score: 0.72

# %% [markdown]
# ## TF-IDF Cosine

# %%
from models.cosine import TFIDFCosineQA

model = TFIDFCosineQA(corpora_path)

MAP = []
tfidf = []
for i, q1 in enumerate(testset):
    y_real, y_pred = [], []
    for row in testset[q1]:
        q2 = row['question']
        label = row['label']
        score = model.score_pair(q1, q2)
        y_real.append(1 if label in ['S', 'R'] else 0)
        y_pred.append(score)

        tfidf.append({
            'qid': i+1,
            'class': 2 if label == 'S' else 1 if label == 'R' else 0,
            'score': score,
            'q': q1,
            'candidate': q2
        })

    if len(list(set(y_real))) > 1:
        MAP.append(average_precision_score(y_real, y_pred))
print("TF-IDF Score:", round(np.mean(MAP), 2))
# Out:
# TF-IDF Score: 0.78

# %% [markdown]
# ## SoftCosine with BERT

# %%
from models.softcosine import TFIDFSoftCosineQA

pretrained = '/home/tcastrof/BeteQA/live/neuralmind/bert-large-portuguese-cased'
model = TFIDFSoftCosineQA(corpora_path, pretrained, pretrained)

softcosine = []
MAP = []
for q1 in testset:
  y_real, y_pred = [], []
  for row in testset[q1]:
    q2 = row['question']
    label = row['label']
    score = model.score_pair(q1, q2)
    y_real.append(1 if label in ['S', 'R'] else 0)
    y_pred.append(score)

    softcosine.append({
        'qid': i+1,
        'class': 2 if label == 'S' else 1 if label == 'R' else 0,
        'score': score,
        'q': q1,
        'candidate': q2
    })

    if len(list(set(y_real))) > 1:
      MAP.append(average_precision_score(y_real, y_pred))
print("SoftCosine with BERT Score:", round(np.mean(MAP), 2))
# Out:
# SoftCosine with BERT Score: 0.7

# %% [markdown]
# ## BERT

# %%
from models.bert import BERTQA

pretrained = '/home/tcastrof/BeteQA/live/neuralmind/bert-large-portuguese-cased'
model = BERTQA(corpora_path, pretrained, pretrained)

bert = []
MAP = []
for q1 in testset:
  y_real, y_pred = [], []
  for row in testset[q1]:
    q2 = row['question']
    label = row['label']
    score = model.score_pair(q1, q2)
    y_real.append(1 if label in ['S', 'R'] else 0)
    y_pred.append(score)
    
    bert.append({
        'qid': i+1,
        'class': 2 if label == 'S' else 1 if label == 'R' else 0,
        'score': score,
        'q': q1,
        'candidate': q2
    })
    
    if len(list(set(y_real))) > 1:
      MAP.append(average_precision_score(y_real, y_pred))
print("BERT Score:", round(np.mean(MAP), 2))
# Out:
# BERT Score: 0.82

# %% [markdown]
# ## MUSE

# %%
from models.muse import MUSEQA

model = MUSEQA(corpora_path, '/home/tcastrof/BeteQA/live/muse_large')

muse = []
MAP = []
for q1 in testset:
  y_real, y_pred = [], []
  for row in testset[q1]:
    q2 = row['question']
    label = row['label']
    score = model.score_pair(q1, q2)
    y_real.append(1 if label in ['S', 'R'] else 0)
    y_pred.append(score)
    
    muse.append({
        'qid': i+1,
        'class': 2 if label == 'S' else 1 if label == 'R' else 0,
        'score': score,
        'q': q1,
        'candidate': q2
    })
    
    if len(list(set(y_real))) > 1:
      MAP.append(average_precision_score(y_real, y_pred))
print("MUSE Score:", round(np.mean(MAP), 2))
# Out:
# INFO:absl:resolver HttpCompressedFileResolver does not support the provided handle.
# INFO:absl:resolver GcsCompressedFileResolver does not support the provided handle.
# MUSE Score: 0.86

# %%
import json

inps = []
for i, row in enumerate(bm25):
    inps.append({
            'qid': row['qid'],
            'user_question': row['q'],
            'candidate_question': row['candidate'],
            'class': row['class'],
            'features':{
                'bm25': float(bm25[i]['score']),
                'cosine': float(tfidf[i]['score']),
                'softcosine': float(softcosine[i]['score']),
                'bert': float(bert[i]['score']),
                'muse': float(muse[i]['score'])
            }
        })

json.dump(inps, open('features.json', 'w'), separators=(',', ':'), indent=4)
inps
# Out:
# [{'candidate_question': 'P: O que é cetoacidose e quais são os sintomas?',
#   'class': 1,
#   'features': {'bert': 0.835228681564331,
#    'bm25': 1.4439651447028046,
#    'cosine': 0.034445135069625606,
#    'muse': 0.3695560097694397,
#    'softcosine': 2.038156970661842},
#   'qid': 1,
#   'user_question': 'P: Nos últimos três dias, a respiração do meu marido cheirava fortemente ácida. Isso está relacionado ao diabetes dele?'},
#  {'candidate_question': 'P: O diabetes pode aumentar os níveis de álcool no sangue?',
#   'class': 0,
#   'features': {'bert': 0.8718256950378418,
#    'bm25': 2.1754401797214653,
#    'cosine': 0.0466609857594224,
#    'muse': 0.46813875436782837,
#    'softcosine': 2.6553348310586182},
#   'qid': 2,
#   'user_question': 'P: Nos últimos três dias, a respiração do meu marido cheirava fortemente ácida. Isso está relacionado ao diabetes dele?'},
#  {'candidate_question': 'Quais são os sinais da cetoacidose?',
#   'class': 1,
#   'features': {'bert': 0.8240658640861511,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.2660662829875946,
#    'softcosine': 2.099381885187217},
#   'qid': 3,
#   'user_question': 'P: Nos últimos três dias, a respiração do meu marido cheirava fortemente ácida. Isso está relacionado ao diabetes dele?'},
#  {'candidate_question': 'Gostaria de saber sobre a cetoacidose diabética',
#   'class': 1,
#   'features': {'bert': 0.8301887512207031,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.5016259551048279,
#    'softcosine': 2.049189316003424},
#   'qid': 4,
#   'user_question': 'P: Nos últimos três dias, a respiração do meu marido cheirava fortemente ácida. Isso está relacionado ao diabetes dele?'},
#  {'candidate_question': 'Q: O que é DKA Meu filho tem tipo 1 e seu médico diz que isso está causando vômito e náusea.',
#   'class': 0,
#   'features': {'bert': 0.8946869969367981,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.26238855719566345,
#    'softcosine': 3.5465146746124265},
#   'qid': 5,
#   'user_question': 'P: Nos últimos três dias, a respiração do meu marido cheirava fortemente ácida. Isso está relacionado ao diabetes dele?'},
#  {'candidate_question': 'P: Eu tenho diabetes tipo 1 há 35 anos. Ultimamente, tenho sido incapaz de me aquecer e me sentir constantemente com frio. O sentimento de frio é sempre causado pelo diabetes?',
#   'class': 0,
#   'features': {'bert': 0.8812093138694763,
#    'bm25': 10.426909072109591,
#    'cosine': 0.16356593142081366,
#    'muse': 0.4992367625236511,
#    'softcosine': 2.4404954945828514},
#   'qid': 1,
#   'user_question': 'P: Li que pessoas com diabetes não devem usar almofadas de aquecimento. Por que não?'},
#  {'candidate_question': 'P: O diabetes pode fazer com que os pés de uma pessoa tenham um odor ruim?',
#   'class': 0,
#   'features': {'bert': 0.8992588520050049,
#    'bm25': 6.563054964448515,
#    'cosine': 0.16292660643992601,
#    'muse': 0.4296039938926697,
#    'softcosine': 2.5371958263302457},
#   'qid': 2,
#   'user_question': 'P: Li que pessoas com diabetes não devem usar almofadas de aquecimento. Por que não?'},
#  {'candidate_question': 'Hoje estou sentindo muita dor nas panturrilhas, será que é normal para quem tem diabetes?',
#   'class': 0,
#   'features': {'bert': 0.8658291697502136,
#    'bm25': 0.8276040317072094,
#    'cosine': 0.023138210903620827,
#    'muse': 0.3629930019378662,
#    'softcosine': 2.5616356876922297},
#   'qid': 3,
#   'user_question': 'P: Li que pessoas com diabetes não devem usar almofadas de aquecimento. Por que não?'},
#  {'candidate_question': 'Meus pés todo tempo estão dormentes, e ficam quentes também. Tem algo que posso fazer para melhorar esse problema?',
#   'class': 0,
#   'features': {'bert': 0.8729897737503052,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.30894041061401367,
#    'softcosine': 2.8404601482704237},
#   'qid': 4,
#   'user_question': 'P: Li que pessoas com diabetes não devem usar almofadas de aquecimento. Por que não?'},
#  {'candidate_question': 'P: Sou mais propenso a infecções se tiver diabetes?',
#   'class': 0,
#   'features': {'bert': 0.8680837750434875,
#    'bm25': 2.4613322085960334,
#    'cosine': 0.06075730188331484,
#    'muse': 0.4472874104976654,
#    'softcosine': 1.8610455566282957},
#   'qid': 5,
#   'user_question': 'P: Li que pessoas com diabetes não devem usar almofadas de aquecimento. Por que não?'},
#  {'candidate_question': 'P: Preciso jejuar antes de um teste A1C?',
#   'class': 2,
#   'features': {'bert': 0.9922733902931213,
#    'bm25': 27.38080502854555,
#    'cosine': 0.9658617717745133,
#    'muse': 0.9930626153945923,
#    'softcosine': 2.9485820005988206},
#   'qid': 1,
#   'user_question': 'P: Preciso jejuar antes de fazer o teste A1C?'},
#  {'candidate_question': 'Q: Qual é o teste A1C?',
#   'class': 1,
#   'features': {'bert': 0.8962073922157288,
#    'bm25': 10.392577640643655,
#    'cosine': 0.4603373800590811,
#    'muse': 0.5583001375198364,
#    'softcosine': 2.4560597908289807},
#   'qid': 2,
#   'user_question': 'P: Preciso jejuar antes de fazer o teste A1C?'},
#  {'candidate_question': 'P: Eu fiz um exame de sangue, mas não percebi que deveria jejuar antes. Tomei duas xícaras de café pela manhã e um sanduíche com batatas fritas no almoço. Meus resultados voltaram às 293. Este é um teste preciso? Eu tenho diabetes? Meu médico quer me colocar em medicação.',
#   'class': 1,
#   'features': {'bert': 0.8811351656913757,
#    'bm25': 21.841907736891205,
#    'cosine': 0.30969992714245537,
#    'muse': 0.5838563442230225,
#    'softcosine': 3.5359556377246184},
#   'qid': 3,
#   'user_question': 'P: Preciso jejuar antes de fazer o teste A1C?'},
#  {'candidate_question': 'P: O que é um nível normal de açúcar no sangue?',
#   'class': 0,
#   'features': {'bert': 0.8457730412483215,
#    'bm25': 1.708573976716535,
#    'cosine': 0.06107963359669984,
#    'muse': 0.41205933690071106,
#    'softcosine': 2.4124420478395434},
#   'qid': 4,
#   'user_question': 'P: Preciso jejuar antes de fazer o teste A1C?'},
#  {'candidate_question': 'P: Você concorda que, embora os padrões de laboratório digam que eu estou bem no meio dos "valores normais de faixa" com um peptídeo C em 2,5, metade das minhas células B desapareceu? Qual seria a pontuação ideal do peptídeo C? Meu A1C atual é 5,9.',
#   'class': 0,
#   'features': {'bert': 0.8426696062088013,
#    'bm25': 7.247471268370878,
#    'cosine': 0.08023466032943696,
#    'muse': 0.2988879084587097,
#    'softcosine': 3.450676404579723},
#   'qid': 5,
#   'user_question': 'P: Preciso jejuar antes de fazer o teste A1C?'},
#  {'candidate_question': 'P: Quanto tempo devo jejuar antes de fazer um exame de glicemia em jejum?',
#   'class': 2,
#   'features': {'bert': 0.9835762977600098,
#    'bm25': 23.201993895767657,
#    'cosine': 0.6329777844818693,
#    'muse': 0.8196372985839844,
#    'softcosine': 3.9549705454217663},
#   'qid': 1,
#   'user_question': 'P: Por que eu preciso jejuar por 10 horas antes de fazer um exame de glicemia em jejum?'},
#  {'candidate_question': 'P: Quanto tempo leva para você comer para que a comida se quebre e se transforme em açúcar?',
#   'class': 1,
#   'features': {'bert': 0.831141471862793,
#    'bm25': 1.5021240685685853,
#    'cosine': 0.03185399059684447,
#    'muse': 0.3782074451446533,
#    'softcosine': 2.7139803840805765},
#   'qid': 2,
#   'user_question': 'P: Por que eu preciso jejuar por 10 horas antes de fazer um exame de glicemia em jejum?'},
#  {'candidate_question': 'P: Um nutricionista me informou que se você equilibrar carboidratos com proteínas, a comida não se transforma em açúcar tão rápido. Meu médico nunca ouviu falar disso - isso é algo novo?',
#   'class': 0,
#   'features': {'bert': 0.8721690773963928,
#    'bm25': 1.5021240685685853,
#    'cosine': 0.01969929544795354,
#    'muse': 0.39910590648651123,
#    'softcosine': 3.800316822840774},
#   'qid': 3,
#   'user_question': 'P: Por que eu preciso jejuar por 10 horas antes de fazer um exame de glicemia em jejum?'},
#  {'candidate_question': 'P: Como eu saberia se sou diabético? Quais são os sinais?',
#   'class': 0,
#   'features': {'bert': 0.8867421746253967,
#    'bm25': 1.5021240685685853,
#    'cosine': 0.04897865892976113,
#    'muse': 0.4463842511177063,
#    'softcosine': 2.9438739639083042},
#   'qid': 4,
#   'user_question': 'P: Por que eu preciso jejuar por 10 horas antes de fazer um exame de glicemia em jejum?'},
#  {'candidate_question': 'P: Devo me preocupar em ser diabético com as seguintes leituras: Jejum de açúcar no sangue entre 80 e 100; 200 uma hora depois de uma refeição?',
#   'class': 0,
#   'features': {'bert': 0.931479275226593,
#    'bm25': 8.035781497509557,
#    'cosine': 0.14852294281076822,
#    'muse': 0.5383919477462769,
#    'softcosine': 4.334326832467224},
#   'qid': 5,
#   'user_question': 'P: Por que eu preciso jejuar por 10 horas antes de fazer um exame de glicemia em jejum?'},
#  {'candidate_question': 'P: Posso tomar café preto antes de fazer um exame de glicemia em jejum?',
#   'class': 2,
#   'features': {'bert': 0.9314464330673218,
#    'bm25': 17.162090876435943,
#    'cosine': 0.5315642631084353,
#    'muse': 0.759369969367981,
#    'softcosine': 2.7663583683314195},
#   'qid': 1,
#   'user_question': 'P: Beber café preto afeta o teste de jejum?'},
#  {'candidate_question': 'P: Comer antes de um teste de glicose no diabetes gestacional pode causar imprecisão nos resultados? Antes do teste de glicose de uma hora, comi um pãozinho inteiro com creme de queijo e banana inteira e cerca de 12 oz. de suco de maçã antes de beber o líquido para o teste. Ninguém me disse para não comer ou beber antes do teste. Minha leitura voltou como 157 e agora, depois de fazer 3 dias de dieta, meus níveis de açúcar no sangue não ultrapassaram 80 e chegaram a 52. Minha pergunta é: poderia o teste estar errado e devo pedir para ser testado novamente? ?',
#   'class': 1,
#   'features': {'bert': 0.8868561387062073,
#    'bm25': 40.13019770951458,
#    'cosine': 0.28435013246560703,
#    'muse': 0.3803516924381256,
#    'softcosine': 3.745857968830351},
#   'qid': 2,
#   'user_question': 'P: Beber café preto afeta o teste de jejum?'},
#  {'candidate_question': 'P: Posso beber água durante o período de duas horas antes de testar o açúcar no sangue?',
#   'class': 1,
#   'features': {'bert': 0.92267906665802,
#    'bm25': 11.212025145136934,
#    'cosine': 0.2618804633149946,
#    'muse': 0.4823077917098999,
#    'softcosine': 2.700793487315406},
#   'qid': 3,
#   'user_question': 'P: Beber café preto afeta o teste de jejum?'},
#  {'candidate_question': 'P: O clima quente ou frio afeta os níveis de açúcar no sangue?',
#   'class': 0,
#   'features': {'bert': 0.8792198896408081,
#    'bm25': 6.916317350986327,
#    'cosine': 0.1745028143867781,
#    'muse': 0.4337799549102783,
#    'softcosine': 2.3941341441486736},
#   'qid': 4,
#   'user_question': 'P: Beber café preto afeta o teste de jejum?'},
#  {'candidate_question': 'P: É possível ter diabetes com micção frequente sem sede excessiva? Eu tenho micção freqüente (tenho que me levantar 5-7 vezes durante a noite, mas só bebi 3 copos de água o dia inteiro e antes das 19h). Minha leitura no jejum foi de 118; ler 2 horas após uma refeição (salada de espinafre e frango) era 207. Parece que tenho alguns dos sintomas clássicos. No entanto, NUNCA estou com sede e tenho que me forçar a beber os 2-3 copos de água que tomo.',
#   'class': 0,
#   'features': {'bert': 0.8416644334793091,
#    'bm25': 14.455375109104198,
#    'cosine': 0.11298026306056928,
#    'muse': 0.3847322463989258,
#    'softcosine': 3.227716293977793},
#   'qid': 5,
#   'user_question': 'P: Beber café preto afeta o teste de jejum?'},
#  {'candidate_question': 'P: Qual é o intervalo normal que o açúcar no sangue deve estar se você testá-lo em casa?',
#   'class': 0,
#   'features': {'bert': 0.8997063040733337,
#    'bm25': 4.322598441732918,
#    'cosine': 0.08179136288737202,
#    'muse': 0.5855751037597656,
#    'softcosine': 4.1733562761668415},
#   'qid': 1,
#   'user_question': 'P: Se eu tenho alguns dos fatores de risco para diabetes, com que frequência devo fazer o teste para descobrir se o tenho ou não?'},
#  {'candidate_question': 'P: Quais são os riscos quando o açúcar no sangue é de 400 a 500?',
#   'class': 0,
#   'features': {'bert': 0.9139695167541504,
#    'bm25': 6.2460263968175145,
#    'cosine': 0.1796004780110052,
#    'muse': 0.5539141893386841,
#    'softcosine': 3.792344900714475},
#   'qid': 2,
#   'user_question': 'P: Se eu tenho alguns dos fatores de risco para diabetes, com que frequência devo fazer o teste para descobrir se o tenho ou não?'},
#  {'candidate_question': 'O que uma pessoa que se encaixa em algum dos grupos de risco deve fazer?',
#   'class': 2,
#   'features': {'bert': 0.8835186958312988,
#    'bm25': 9.82113826619128,
#    'cosine': 0.25008739050152184,
#    'muse': 0.35194337368011475,
#    'softcosine': 3.776591741897829},
#   'qid': 3,
#   'user_question': 'P: Se eu tenho alguns dos fatores de risco para diabetes, com que frequência devo fazer o teste para descobrir se o tenho ou não?'},
#  {'candidate_question': 'P: Qual é a melhor maneira de testar o diabetes tipo 1? Existe uma chance de um exame de sangue estar errado?',
#   'class': 1,
#   'features': {'bert': 0.9444080591201782,
#    'bm25': 6.530262768526822,
#    'cosine': 0.12481349966127078,
#    'muse': 0.7213157415390015,
#    'softcosine': 4.560847198583816},
#   'qid': 4,
#   'user_question': 'P: Se eu tenho alguns dos fatores de risco para diabetes, com que frequência devo fazer o teste para descobrir se o tenho ou não?'},
#  {'candidate_question': 'Meu Deus, eu estou indisposta hoje, estou com um barulho na minha cabeça e a minha pressão está em 9. Eu estou tão mal que só Deus na minha vida.',
#   'class': 0,
#   'features': {'bert': 0.8218116164207458,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.11733336001634598,
#    'softcosine': 3.5535523637841955},
#   'qid': 5,
#   'user_question': 'P: Se eu tenho alguns dos fatores de risco para diabetes, com que frequência devo fazer o teste para descobrir se o tenho ou não?'},
#  {'candidate_question': 'Diabetes tem cura?',
#   'class': 2,
#   'features': {'bert': 0.8864699602127075,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.6905461549758911,
#    'softcosine': 1.6048583808153565},
#   'qid': 1,
#   'user_question': 'P: É possível parar de ser diabético?'},
#  {'candidate_question': 'P: Por que sinto dor de cabeça e começo a sentir náuseas quando como ou bebo algo doce?',
#   'class': 0,
#   'features': {'bert': 0.801819920539856,
#    'bm25': 1.8809141842477546,
#    'cosine': 0.04127592902835898,
#    'muse': 0.34720075130462646,
#    'softcosine': 2.2625954512406925},
#   'qid': 2,
#   'user_question': 'P: É possível parar de ser diabético?'},
#  {'candidate_question': 'P: O diabetes pode afetar meu controle da bexiga?',
#   'class': 0,
#   'features': {'bert': 0.8969876766204834,
#    'bm25': 1.8809141842477546,
#    'cosine': 0.05800053107582227,
#    'muse': 0.6758143305778503,
#    'softcosine': 2.337715972662619},
#   'qid': 3,
#   'user_question': 'P: É possível parar de ser diabético?'},
#  {'candidate_question': 'P: Que tipo de medicamentos são usados \u200b\u200bpara tratar o pré-diabetes?',
#   'class': 0,
#   'features': {'bert': 0.9226283431053162,
#    'bm25': 1.8809141842477546,
#    'cosine': 0.04181708110713119,
#    'muse': 0.45030251145362854,
#    'softcosine': 2.53147664365807},
#   'qid': 4,
#   'user_question': 'P: É possível parar de ser diabético?'},
#  {'candidate_question': 'P: Disseram-me que tenho diabetes, ou "pré-diabetes", ou que estou no "período de lua de mel". Minhas leituras estão por todo o lado: às vezes nos anos 120, outras nos anos 90, às vezes, mas raramente nos 150-170. Meu médico ainda não quer me medicar. Faço exercícios regularmente e não estou acima do peso, embora minha dieta seja variável. Eu certamente gosto de doces, pizza e macarrão. Qual é o efeito a longo prazo desses níveis elevados de açúcar no sangue continuados?',
#   'class': 0,
#   'features': {'bert': 0.8245394229888916,
#    'bm25': 1.8809141842477546,
#    'cosine': 0.014741924662993202,
#    'muse': 0.40921443700790405,
#    'softcosine': 3.146612412605453},
#   'qid': 5,
#   'user_question': 'P: É possível parar de ser diabético?'},
#  {'candidate_question': 'P: Meus dedos estão doloridos. Existe algum outro lugar no meu corpo que eu possa usar para verificar meu açúcar?',
#   'class': 2,
#   'features': {'bert': 0.9373946785926819,
#    'bm25': 18.03238661748079,
#    'cosine': 0.33339105092733384,
#    'muse': 0.5986056327819824,
#    'softcosine': 4.576865309533961},
#   'qid': 1,
#   'user_question': 'P: Minhas pontas dos dedos estão doendo devido aos testes. Importa se eu tirar minha amostra de sangue de outro lugar do meu corpo?'},
#  {'candidate_question': 'P: Sou iniciante no diabetes e estou tendo problemas para me testar para medir o açúcar no sangue.',
#   'class': 1,
#   'features': {'bert': 0.8576313257217407,
#    'bm25': 7.585318111928381,
#    'cosine': 0.15873506866391646,
#    'muse': 0.3893222212791443,
#    'softcosine': 3.4416097361598355},
#   'qid': 2,
#   'user_question': 'P: Minhas pontas dos dedos estão doendo devido aos testes. Importa se eu tirar minha amostra de sangue de outro lugar do meu corpo?'},
#  {'candidate_question': 'P: Que dedo devo usar ao testar? Em duas ocasiões, tive leituras diferentes de dois dedos diferentes.',
#   'class': 1,
#   'features': {'bert': 0.8972315192222595,
#    'bm25': 16.23774063987787,
#    'cosine': 0.22315653495743956,
#    'muse': 0.46209079027175903,
#    'softcosine': 3.4050160079877685},
#   'qid': 3,
#   'user_question': 'P: Minhas pontas dos dedos estão doendo devido aos testes. Importa se eu tirar minha amostra de sangue de outro lugar do meu corpo?'},
#  {'candidate_question': 'Boa noite, vocês também ficam com as pontas dos dedos da mão doendo de tanto que furam para verificar a glicemia?',
#   'class': 2,
#   'features': {'bert': 0.8916404247283936,
#    'bm25': 14.68480829616891,
#    'cosine': 0.31411412917132175,
#    'muse': 0.5810244083404541,
#    'softcosine': 3.8379442602948366},
#   'qid': 4,
#   'user_question': 'P: Minhas pontas dos dedos estão doendo devido aos testes. Importa se eu tirar minha amostra de sangue de outro lugar do meu corpo?'},
#  {'candidate_question': 'P: Acabei de adquirir um novo monitor de glicose e meus números são mais baixos do que no meu monitor antigo - até uma diferença de 23 pontos. Estou curioso para saber por que isso seria?',
#   'class': 0,
#   'features': {'bert': 0.8874289989471436,
#    'bm25': 6.126690593703937,
#    'cosine': 0.08407946557360012,
#    'muse': 0.27304860949516296,
#    'softcosine': 3.7652127273760603},
#   'qid': 5,
#   'user_question': 'P: Minhas pontas dos dedos estão doendo devido aos testes. Importa se eu tirar minha amostra de sangue de outro lugar do meu corpo?'},
#  {'candidate_question': 'Gostaria de saber sobre o pré-diabetes',
#   'class': 1,
#   'features': {'bert': 0.8711429238319397,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.48285096883773804,
#    'softcosine': 1.6519987141443457},
#   'qid': 1,
#   'user_question': 'P: A obesidade causa diabetes tipo 2?'},
#  {'candidate_question': 'O diabetes prejudica o fígado?',
#   'class': 1,
#   'features': {'bert': 0.9158830046653748,
#    'bm25': 0.9070746660607034,
#    'cosine': 0.04125036197279314,
#    'muse': 0.6464194655418396,
#    'softcosine': 1.7434106661616982},
#   'qid': 2,
#   'user_question': 'P: A obesidade causa diabetes tipo 2?'},
#  {'candidate_question': 'O que percebi é que consumimos muito mais carboidratos do que imaginava. Isso pode ser um agravante para que venhamos a desenvolver diabetes tipo 2 ao longo da vida?',
#   'class': 0,
#   'features': {'bert': 0.8663827180862427,
#    'bm25': 6.835666480342081,
#    'cosine': 0.1200777185886826,
#    'muse': 0.6155400276184082,
#    'softcosine': 2.3439921319387937},
#   'qid': 3,
#   'user_question': 'P: A obesidade causa diabetes tipo 2?'},
#  {'candidate_question': 'Como é o diabetes tipo 2?',
#   'class': 2,
#   'features': {'bert': 0.9176751971244812,
#    'bm25': 6.835666480342081,
#    'cosine': 0.4349145986457904,
#    'muse': 0.6566832065582275,
#    'softcosine': 2.3310554288589875},
#   'qid': 4,
#   'user_question': 'P: A obesidade causa diabetes tipo 2?'},
#  {'candidate_question': 'O que acontece com quem tem diabetes tipo 2?',
#   'class': 2,
#   'features': {'bert': 0.917396068572998,
#    'bm25': 6.835666480342081,
#    'cosine': 0.3206490503776166,
#    'muse': 0.6279224157333374,
#    'softcosine': 2.5393406256807713},
#   'qid': 5,
#   'user_question': 'P: A obesidade causa diabetes tipo 2?'},
#  {'candidate_question': 'Eu pergunto por que a diabetes não tem cura e porque a diabetes aparece sem a gente perceber.',
#   'class': 1,
#   'features': {'bert': 0.888973593711853,
#    'bm25': 1.1871638970469023,
#    'cosine': 0.03309708890831172,
#    'muse': 0.3912331461906433,
#    'softcosine': 4.026417754656734},
#   'qid': 1,
#   'user_question': 'P: Se uma criança de 13 anos é diagnosticada com diabetes, ela é sempre do tipo 1 e precisa estar em uso de insulina ou pode ser controlada pela dieta?'},
#  {'candidate_question': 'Gostaria de saber mais sobre a diabetes, a insulina, o efeito que faz, bem ou mal.',
#   'class': 1,
#   'features': {'bert': 0.9113304615020752,
#    'bm25': 2.6845596805311507,
#    'cosine': 0.07642512942145223,
#    'muse': 0.4709515869617462,
#    'softcosine': 4.852336698025054},
#   'qid': 2,
#   'user_question': 'P: Se uma criança de 13 anos é diagnosticada com diabetes, ela é sempre do tipo 1 e precisa estar em uso de insulina ou pode ser controlada pela dieta?'},
#  {'candidate_question': 'P: Um diagnóstico de diabetes tipo 2 significa que vou ter que tomar insulina?',
#   'class': 0,
#   'features': {'bert': 0.9356005191802979,
#    'bm25': 5.676287039707318,
#    'cosine': 0.12371063469118698,
#    'muse': 0.6388868093490601,
#    'softcosine': 4.204722152021976},
#   'qid': 3,
#   'user_question': 'P: Se uma criança de 13 anos é diagnosticada com diabetes, ela é sempre do tipo 1 e precisa estar em uso de insulina ou pode ser controlada pela dieta?'},
#  {'candidate_question': 'É possível ser diabético com menos de 25 anos de idade?',
#   'class': 2,
#   'features': {'bert': 0.8724400401115417,
#    'bm25': 4.963253524471748,
#    'cosine': 0.10918044238341498,
#    'muse': 0.5606485605239868,
#    'softcosine': 3.375994983003738},
#   'qid': 4,
#   'user_question': 'P: Se uma criança de 13 anos é diagnosticada com diabetes, ela é sempre do tipo 1 e precisa estar em uso de insulina ou pode ser controlada pela dieta?'},
#  {'candidate_question': 'P: Que impacto o diabetes do meu marido teria em nosso futuro filho se decidirmos ter um bebê?',
#   'class': 0,
#   'features': {'bert': 0.8858091831207275,
#    'bm25': 1.7653398393047435,
#    'cosine': 0.033906667172583504,
#    'muse': 0.4957980811595917,
#    'softcosine': 4.178684592558507},
#   'qid': 5,
#   'user_question': 'P: Se uma criança de 13 anos é diagnosticada com diabetes, ela é sempre do tipo 1 e precisa estar em uso de insulina ou pode ser controlada pela dieta?'},
#  {'candidate_question': 'O diabetes atrapalha o sono?',
#   'class': 2,
#   'features': {'bert': 0.8890606164932251,
#    'bm25': 0.7042095959427684,
#    'cosine': 0.024923144214190084,
#    'muse': 0.5673438906669617,
#    'softcosine': 1.915303066429852},
#   'qid': 1,
#   'user_question': 'P: Como posso ajudar meu filho adulto com diabetes tipo 1 a dormir bem? Ele tem dificuldade em adormecer.'},
#  {'candidate_question': 'A diabetes atrapalha o sono?',
#   'class': 2,
#   'features': {'bert': 0.88843834400177,
#    'bm25': 0.7042095959427684,
#    'cosine': 0.02394657007454782,
#    'muse': 0.5636685490608215,
#    'softcosine': 1.9571560638635201},
#   'qid': 2,
#   'user_question': 'P: Como posso ajudar meu filho adulto com diabetes tipo 1 a dormir bem? Ele tem dificuldade em adormecer.'},
#  {'candidate_question': 'Por que a diabetes atrapalha o sono?',
#   'class': 2,
#   'features': {'bert': 0.8862329721450806,
#    'bm25': 0.7042095959427684,
#    'cosine': 0.02428035979281114,
#    'muse': 0.5799362063407898,
#    'softcosine': 2.08535384843261},
#   'qid': 3,
#   'user_question': 'P: Como posso ajudar meu filho adulto com diabetes tipo 1 a dormir bem? Ele tem dificuldade em adormecer.'},
#  {'candidate_question': 'Por que meu sono está derregulado?',
#   'class': 2,
#   'features': {'bert': 0.8492028713226318,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.33442917466163635,
#    'softcosine': 2.200603241000973},
#   'qid': 4,
#   'user_question': 'P: Como posso ajudar meu filho adulto com diabetes tipo 1 a dormir bem? Ele tem dificuldade em adormecer.'},
#  {'candidate_question': 'A síndrome da fome noturna tem tratamento?',
#   'class': 0,
#   'features': {'bert': 0.8598964214324951,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.34945058822631836,
#    'softcosine': 2.0766935138832974},
#   'qid': 5,
#   'user_question': 'P: Como posso ajudar meu filho adulto com diabetes tipo 1 a dormir bem? Ele tem dificuldade em adormecer.'},
#  {'candidate_question': 'P: Meu marido com diabetes tipo 2 está tentando diminuir o açúcar no sangue fazendo uma dieta baixa em carboidratos e pulando o almoço. Ele está tendo problemas com o aumento da leitura noturna. Ele deveria comer refeições regulares?',
#   'class': 0,
#   'features': {'bert': 0.8861169219017029,
#    'bm25': 3.207026917074885,
#    'cosine': 0.20294656273220316,
#    'muse': 0.4878624677658081,
#    'softcosine': 4.99473628578814},
#   'qid': 1,
#   'user_question': 'P: Meu namorado é diabético. Ele é meio rebelde e não testa seus níveis. Pelo menos uma vez por mês, ele se transforma no que eu chamo de "zumbi". Ele começa a ficar suado / úmido, ele tende a ser esquecido, ele se repete e, desta última vez, estava totalmente fora de si e ficou violento. Quando o confrontei depois, ele não se lembrava de fazê-lo. Como eu o ajudo?'},
#  {'candidate_question': 'P: Meu pai de 66 anos tem diabetes. Ele tem manchas de pele muito secas nas costas principalmente. Eles ficam um pouco escamosos e coçam muito. Esse é um sintoma típico do diabetes? O que você sugere para alívio?',
#   'class': 0,
#   'features': {'bert': 0.9045313000679016,
#    'bm25': 3.3823808844531302,
#    'cosine': 0.14141371547466708,
#    'muse': 0.5297405123710632,
#    'softcosine': 5.174830565626336},
#   'qid': 2,
#   'user_question': 'P: Meu namorado é diabético. Ele é meio rebelde e não testa seus níveis. Pelo menos uma vez por mês, ele se transforma no que eu chamo de "zumbi". Ele começa a ficar suado / úmido, ele tende a ser esquecido, ele se repete e, desta última vez, estava totalmente fora de si e ficou violento. Quando o confrontei depois, ele não se lembrava de fazê-lo. Como eu o ajudo?'},
#  {'candidate_question': 'P: Eu tenho diabetes tipo 2 e tomo insulina há um ano. Perdi um pouco de peso e meu A1C caiu de 9,5 para 6,5, mas estou tendo muitos pontos baixos que vão dos 40 aos 60 anos. Gostaria de saber se talvez eu consiga sair da insulina. Sinto que meu médico oral está começando a funcionar melhor agora que minhas células beta descansaram. Isso pode ser verdade?',
#   'class': 0,
#   'features': {'bert': 0.9105660915374756,
#    'bm25': 6.905329786697434,
#    'cosine': 0.05373986754950617,
#    'muse': 0.39679282903671265,
#    'softcosine': 6.641140403745284},
#   'qid': 3,
#   'user_question': 'P: Meu namorado é diabético. Ele é meio rebelde e não testa seus níveis. Pelo menos uma vez por mês, ele se transforma no que eu chamo de "zumbi". Ele começa a ficar suado / úmido, ele tende a ser esquecido, ele se repete e, desta última vez, estava totalmente fora de si e ficou violento. Quando o confrontei depois, ele não se lembrava de fazê-lo. Como eu o ajudo?'},
#  {'candidate_question': 'P: As leituras baixas de açúcar no sangue de 60 ou 70 afetam meu nível de A1C?',
#   'class': 0,
#   'features': {'bert': 0.8235105276107788,
#    'bm25': 0.7637969558690174,
#    'cosine': 0.010455168489647546,
#    'muse': 0.35660815238952637,
#    'softcosine': 3.6101093056173554},
#   'qid': 4,
#   'user_question': 'P: Meu namorado é diabético. Ele é meio rebelde e não testa seus níveis. Pelo menos uma vez por mês, ele se transforma no que eu chamo de "zumbi". Ele começa a ficar suado / úmido, ele tende a ser esquecido, ele se repete e, desta última vez, estava totalmente fora de si e ficou violento. Quando o confrontei depois, ele não se lembrava de fazê-lo. Como eu o ajudo?'},
#  {'candidate_question': 'P: Por que meu filho de 13 anos se levanta de repente no meio da noite com pouco açúcar no sangue? Ele come no horário exato e garante que eu faça a insulina ou a verifique para ter certeza de que está correta. Ele usa Humalog e Humulin N.',
#   'class': 0,
#   'features': {'bert': 0.9148379564285278,
#    'bm25': 3.1465217541099797,
#    'cosine': 0.1541847903866698,
#    'muse': 0.4162522256374359,
#    'softcosine': 5.880147858314001},
#   'qid': 5,
#   'user_question': 'P: Meu namorado é diabético. Ele é meio rebelde e não testa seus níveis. Pelo menos uma vez por mês, ele se transforma no que eu chamo de "zumbi". Ele começa a ficar suado / úmido, ele tende a ser esquecido, ele se repete e, desta última vez, estava totalmente fora de si e ficou violento. Quando o confrontei depois, ele não se lembrava de fazê-lo. Como eu o ajudo?'},
#  {'candidate_question': 'P: O diabetes ocorre em minha família, por isso estou preocupado em ir ao banheiro com muito mais frequência. Eu bebo uma boa quantidade de colas dietéticas.',
#   'class': 0,
#   'features': {'bert': 0.8593966364860535,
#    'bm25': 9.287821827284127,
#    'cosine': 0.183255197651157,
#    'muse': 0.4879540205001831,
#    'softcosine': 2.77373005618761},
#   'qid': 1,
#   'user_question': 'P: Um diabético pode usar uma banheira de hidromassagem?'},
#  {'candidate_question': 'Gente, me tirem uma dúvida. Estou com a glicemia controlada, mas confesso que não bebo muita água, no máximo 1 litro diário. Minha urina está muito fedorenta, cheira mal. Não faço xixi o tempo todo também, vou, no máximo, umas 3 vezes ao banheiro. O que pode ser?',
#   'class': 0,
#   'features': {'bert': 0.8228768110275269,
#    'bm25': 9.423089378845694,
#    'cosine': 0.12148081915196025,
#    'muse': 0.38881736993789673,
#    'softcosine': 2.8212825183573647},
#   'qid': 2,
#   'user_question': 'P: Um diabético pode usar uma banheira de hidromassagem?'},
#  {'candidate_question': 'Amigos, boa tarde. Alguém pode me ajudar indicando um medicamento para má circulação?',
#   'class': 0,
#   'features': {'bert': 0.8233344554901123,
#    'bm25': 1.9258743921643737,
#    'cosine': 0.0365022718264789,
#    'muse': 0.28300508856773376,
#    'softcosine': 2.3879467620351367},
#   'qid': 3,
#   'user_question': 'P: Um diabético pode usar uma banheira de hidromassagem?'},
#  {'candidate_question': 'P: Meu marido está em uma bomba de insulina, mas após um nível baixo de açúcar no sangue, ele luta por várias semanas para controlar novamente seus açúcares no sangue. Os açúcares no sangue diminuem e depois aumentam sem motivo, independentemente da dieta, exercício, insulina.',
#   'class': 0,
#   'features': {'bert': 0.8268979787826538,
#    'bm25': 1.7906068406028073,
#    'cosine': 0.01776211144760167,
#    'muse': 0.38068073987960815,
#    'softcosine': 2.805899865909598},
#   'qid': 4,
#   'user_question': 'P: Um diabético pode usar uma banheira de hidromassagem?'},
#  {'candidate_question': 'Bom dia. Mais alguém sente muita dor nas pernas e indisposição?',
#   'class': 0,
#   'features': {'bert': 0.778264045715332,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.25436216592788696,
#    'softcosine': 1.8283434481161815},
#   'qid': 5,
#   'user_question': 'P: Um diabético pode usar uma banheira de hidromassagem?'},
#  {'candidate_question': 'P: Meu frasco de insulina expirará no próximo mês. Ainda posso usá-lo ou preciso jogá-lo fora?',
#   'class': 0,
#   'features': {'bert': 0.8312491774559021,
#    'bm25': 5.791404940436497,
#    'cosine': 0.08421921118313336,
#    'muse': 0.39900660514831543,
#    'softcosine': 1.8621106588802303},
#   'qid': 1,
#   'user_question': 'P: As pessoas com diabetes precisam usar creme dental especial?'},
#  {'candidate_question': 'P: A glutamina afeta o pâncreas?',
#   'class': 0,
#   'features': {'bert': 0.8506348729133606,
#    'bm25': 1.6337281768888239,
#    'cosine': 0.03441064613636959,
#    'muse': 0.3272516131401062,
#    'softcosine': 1.8008197724637822},
#   'qid': 2,
#   'user_question': 'P: As pessoas com diabetes precisam usar creme dental especial?'},
#  {'candidate_question': 'P: Vou ter que trocar minha insulina porque a Novo Nordisc está retirando seus produtos Novolin N e R do mercado. Não tenho certeza se a caneta é a melhor para mim, porque uma vez que minha insulina atinge o pico, meu açúcar no sangue cai muito rapidamente. Você tem alguma sugestão de insulina que eu deva pesquisar e perguntar ao meu médico?',
#   'class': 0,
#   'features': {'bert': 0.8728076219558716,
#    'bm25': 1.6337281768888239,
#    'cosine': 0.011693476369624029,
#    'muse': 0.3369600772857666,
#    'softcosine': 3.49704604133653},
#   'qid': 3,
#   'user_question': 'P: As pessoas com diabetes precisam usar creme dental especial?'},
#  {'candidate_question': 'P: Meu medicamento para diabetes está causando dores de cabeça? Não tenho certeza se é o meu novo medicamento (metformina) ou alto nível de açúcar no sangue, mas estou tendo essas dores de cabeça horríveis que me impedem de fazer qualquer coisa o dia inteiro. Meu açúcar no sangue varia de 130-160. Às vezes é 100, mas parece que quando está perto de 100, minhas dores de cabeça são ainda piores.',
#   'class': 0,
#   'features': {'bert': 0.8649765253067017,
#    'bm25': 2.4613322085960334,
#    'cosine': 0.017411493798702306,
#    'muse': 0.3346114456653595,
#    'softcosine': 3.4905124026599967},
#   'qid': 4,
#   'user_question': 'P: As pessoas com diabetes precisam usar creme dental especial?'},
#  {'candidate_question': 'P: Como posso prevenir o diabetes? Tenho 14 anos, excesso de peso e diabetes são comuns em minha família.',
#   'class': 0,
#   'features': {'bert': 0.8900599479675293,
#    'bm25': 3.2889362403032427,
#    'cosine': 0.052774280599646686,
#    'muse': 0.4128769636154175,
#    'softcosine': 2.618814670594801},
#   'qid': 5,
#   'user_question': 'P: As pessoas com diabetes precisam usar creme dental especial?'},
#  {'candidate_question': 'P: É normal que alguém passe de saudável para insulina diabética muito rapidamente? Estou acima do peso há anos e tenho verificado meu açúcar no sangue nas consultas médicas semestrais, sempre para saber que tudo está "bem". De repente, meu A1c é 10.1 com um açúcar no sangue em jejum de 329 e fui diagnosticado como diabético tipo 2 e colocado imediatamente em insulina.',
#   'class': 1,
#   'features': {'bert': 0.9415197968482971,
#    'bm25': 7.072361871096195,
#    'cosine': 0.08549919201973623,
#    'muse': 0.5948509573936462,
#    'softcosine': 7.67449281039126},
#   'qid': 1,
#   'user_question': 'P: Faz apenas algumas semanas desde o meu diagnóstico de Diabetes tipo 2 e estou um pouco assustada porque ainda não vi ninguém mencionar que o A1c está em qualquer lugar do mesmo parque que o meu, que é 11. Estou em grandes problemas ou o quê?'},
#  {'candidate_question': 'P: Estou acima do peso há anos e tenho verificado meu açúcar no sangue em consultas médicas semestrais, sempre para saber que está "bom" ou "normal". Cinco meses atrás, o A1c era de 6,3. Agora foi para 10,1 com um açúcar no sangue em jejum de 329. Enquanto eu estava na minha primeira consulta de gestão de diabéticos, a enfermeira me mostrando como testar meu açúcar no sangue conseguiu um 428, enfiou uma agulha de insulina em mim e me mandou para casa com frascos. e agulhas. É normal que alguém passe da multa para a insulina diabética tão rapidamente?',
#   'class': 1,
#   'features': {'bert': 0.9258214831352234,
#    'bm25': 3.972018248946898,
#    'cosine': 0.04122312334923322,
#    'muse': 0.5739466547966003,
#    'softcosine': 7.6549140439837995},
#   'qid': 2,
#   'user_question': 'P: Faz apenas algumas semanas desde o meu diagnóstico de Diabetes tipo 2 e estou um pouco assustada porque ainda não vi ninguém mencionar que o A1c está em qualquer lugar do mesmo parque que o meu, que é 11. Estou em grandes problemas ou o quê?'},
#  {'candidate_question': 'P: Meu médico quer me colocar em Byetta, pelo principal motivo de melhorar a produção e longevidade de células beta. Você concorda que, embora os padrões de laboratório digam que eu estou bem no meio dos "valores de faixa normal" com um peptídeo C em 2,5, metade das minhas células B desapareceu? Qual seria a pontuação ideal do peptídeo C? Byetta realmente faria o que o médico diz: para ajudar a manter a integridade e a funcionalidade das células B? Sou resistente a fazê-lo por causa do fato de ter que ser injetado e não quero os efeitos colaterais de náusea, distúrbios gástricos, etc. Meu A1C atual é 5,9.',
#   'class': 0,
#   'features': {'bert': 0.9194304347038269,
#    'bm25': 3.972018248946898,
#    'cosine': 0.023246545544704324,
#    'muse': 0.3097116947174072,
#    'softcosine': 8.350226491369812},
#   'qid': 3,
#   'user_question': 'P: Faz apenas algumas semanas desde o meu diagnóstico de Diabetes tipo 2 e estou um pouco assustada porque ainda não vi ninguém mencionar que o A1c está em qualquer lugar do mesmo parque que o meu, que é 11. Estou em grandes problemas ou o quê?'},
#  {'candidate_question': 'P: Existe algum risco de ter diabetes tipo 2 durante a gravidez?',
#   'class': 0,
#   'features': {'bert': 0.8815646767616272,
#    'bm25': 6.443594815414197,
#    'cosine': 0.13001537408406022,
#    'muse': 0.41805726289749146,
#    'softcosine': 3.796427929184895},
#   'qid': 4,
#   'user_question': 'P: Faz apenas algumas semanas desde o meu diagnóstico de Diabetes tipo 2 e estou um pouco assustada porque ainda não vi ninguém mencionar que o A1c está em qualquer lugar do mesmo parque que o meu, que é 11. Estou em grandes problemas ou o quê?'},
#  {'candidate_question': 'P: Perder uma grande quantidade de peso me ajudará a evitar o diabetes que ocorre na minha família? Tenho 19 anos e muito excesso de peso. Recentemente, tomei meu açúcar no sangue algumas vezes e os resultados me assustaram: 170 quando acordei.',
#   'class': 0,
#   'features': {'bert': 0.9241775274276733,
#    'bm25': 10.922785099666886,
#    'cosine': 0.15445968205926222,
#    'muse': 0.37883031368255615,
#    'softcosine': 6.2604308577688315},
#   'qid': 5,
#   'user_question': 'P: Faz apenas algumas semanas desde o meu diagnóstico de Diabetes tipo 2 e estou um pouco assustada porque ainda não vi ninguém mencionar que o A1c está em qualquer lugar do mesmo parque que o meu, que é 11. Estou em grandes problemas ou o quê?'},
#  {'candidate_question': 'A pessoa com diabetes deve tomar mais cuidado com a pele?',
#   'class': 2,
#   'features': {'bert': 0.9082210063934326,
#    'bm25': 11.247412340173206,
#    'cosine': 0.34487847908833597,
#    'muse': 0.6169012188911438,
#    'softcosine': 3.1113387764280915},
#   'qid': 1,
#   'user_question': 'P: Por que as pessoas com diabetes devem ter tanto cuidado ao tratar cortes e outras lesões?'},
#  {'candidate_question': 'Quais cuidados se deve ter com a pele?',
#   'class': 2,
#   'features': {'bert': 0.8699642419815063,
#    'bm25': 10.445652289523068,
#    'cosine': 0.3422151155231702,
#    'muse': 0.27570927143096924,
#    'softcosine': 2.6714916113350506},
#   'qid': 2,
#   'user_question': 'P: Por que as pessoas com diabetes devem ter tanto cuidado ao tratar cortes e outras lesões?'},
#  {'candidate_question': 'O portador de diabetes deve ser mais cuidadoso com a sua pele?',
#   'class': 2,
#   'features': {'bert': 0.910576581954956,
#    'bm25': 3.4427468744065632,
#    'cosine': 0.08173703020722431,
#    'muse': 0.5720669031143188,
#    'softcosine': 3.0559259386309856},
#   'qid': 3,
#   'user_question': 'P: Por que as pessoas com diabetes devem ter tanto cuidado ao tratar cortes e outras lesões?'},
#  {'candidate_question': 'Como cuidar dos pés?',
#   'class': 0,
#   'features': {'bert': 0.8125373125076294,
#    'bm25': 4.179371627740145,
#    'cosine': 0.2094726650872134,
#    'muse': 0.27920714020729065,
#    'softcosine': 1.8948534219344986},
#   'qid': 4,
#   'user_question': 'P: Por que as pessoas com diabetes devem ter tanto cuidado ao tratar cortes e outras lesões?'},
#  {'candidate_question': 'Como tomar cuidado com a pele?',
#   'class': 2,
#   'features': {'bert': 0.8354483842849731,
#    'bm25': 4.179371627740145,
#    'cosine': 0.18028060356576958,
#    'muse': 0.27177539467811584,
#    'softcosine': 2.3056401832031277},
#   'qid': 5,
#   'user_question': 'P: Por que as pessoas com diabetes devem ter tanto cuidado ao tratar cortes e outras lesões?'},
#  {'candidate_question': 'P: Acho que posso ter diabetes porque minha glicemia de jejum é 140, mas meu médico disse que não tenho diabetes. Fico tonto, tonto, olhos embaçados, e minhas mãos tremem se eu não comer um lanche com açúcar entre as refeições. Por favor, ajude, meu médico diz que estou bem.',
#   'class': 0,
#   'features': {'bert': 0.9148896336555481,
#    'bm25': 4.478859174246336,
#    'cosine': 0.04900490040321509,
#    'muse': 0.6720963716506958,
#    'softcosine': 4.561747356118191},
#   'qid': 1,
#   'user_question': 'P: O baixo nível de açúcar no sangue que eu sinto de tempos em tempos pode ser um sinal de que eu poderia estar no caminho da diabetes?'},
#  {'candidate_question': 'P: Quantas frutas posso comer?',
#   'class': 0,
#   'features': {'bert': 0.8208053112030029,
#    'bm25': 1.2503257471174294,
#    'cosine': 0.04087382822939239,
#    'muse': 0.28578126430511475,
#    'softcosine': 2.17982494540434},
#   'qid': 2,
#   'user_question': 'P: O baixo nível de açúcar no sangue que eu sinto de tempos em tempos pode ser um sinal de que eu poderia estar no caminho da diabetes?'},
#  {'candidate_question': 'P: O que é uma boa leitura de açúcar no sangue após uma refeição?',
#   'class': 1,
#   'features': {'bert': 0.9114400744438171,
#    'bm25': 5.486582974336665,
#    'cosine': 0.19051627748277808,
#    'muse': 0.5612793564796448,
#    'softcosine': 3.1976801962409374},
#   'qid': 3,
#   'user_question': 'P: O baixo nível de açúcar no sangue que eu sinto de tempos em tempos pode ser um sinal de que eu poderia estar no caminho da diabetes?'},
#  {'candidate_question': 'P: O que é um açúcar no sangue normal 1 hora depois de comer?',
#   'class': 1,
#   'features': {'bert': 0.9187566041946411,
#    'bm25': 5.486582974336665,
#    'cosine': 0.21576164449560356,
#    'muse': 0.5857002139091492,
#    'softcosine': 3.8122610848028193},
#   'qid': 4,
#   'user_question': 'P: O baixo nível de açúcar no sangue que eu sinto de tempos em tempos pode ser um sinal de que eu poderia estar no caminho da diabetes?'},
#  {'candidate_question': 'Q: Eu tenho um neto de 3 anos. De vez em quando, ele sacode levemente se não comer direito. Eu estou pensando que seu açúcar está baixo. Você poderia me dizer qual deveria ser a contagem de crianças.',
#   'class': 2,
#   'features': {'bert': 0.8869419097900391,
#    'bm25': 9.276837077522547,
#    'cosine': 0.11734451744314446,
#    'muse': 0.4573855400085449,
#    'softcosine': 4.097056185542009},
#   'qid': 5,
#   'user_question': 'P: O baixo nível de açúcar no sangue que eu sinto de tempos em tempos pode ser um sinal de que eu poderia estar no caminho da diabetes?'},
#  {'candidate_question': 'P: Como não tenho diabetes, por que fico tonto e trêmulo sempre que estou ansioso ou com fome?',
#   'class': 0,
#   'features': {'bert': 0.9136416912078857,
#    'bm25': 3.623986359937799,
#    'cosine': 0.09963101955163402,
#    'muse': 0.5895361304283142,
#    'softcosine': 3.89147714908743},
#   'qid': 1,
#   'user_question': 'P: Por que fico extremamente cansado e adormeço depois de comer? Isso é verdade quando como qualquer alimento com açúcares simples maiores, principalmente sobremesas. Estou com sono uma hora depois de comer.'},
#  {'candidate_question': 'P: Quais são os prós e os contras da contagem de carboidratos?',
#   'class': 1,
#   'features': {'bert': 0.8071640729904175,
#    'bm25': 1.1717578907812922,
#    'cosine': 0.02109332308067603,
#    'muse': 0.31762343645095825,
#    'softcosine': 2.4198508930113944},
#   'qid': 2,
#   'user_question': 'P: Por que fico extremamente cansado e adormeço depois de comer? Isso é verdade quando como qualquer alimento com açúcares simples maiores, principalmente sobremesas. Estou com sono uma hora depois de comer.'},
#  {'candidate_question': 'P: Por que meu açúcar no sangue salta de 115 para 165 depois de tomar o café da manhã?',
#   'class': 0,
#   'features': {'bert': 0.9003232717514038,
#    'bm25': 3.0102531290526393,
#    'cosine': 0.08565274565202652,
#    'muse': 0.5880616903305054,
#    'softcosine': 3.3700629082694187},
#   'qid': 3,
#   'user_question': 'P: Por que fico extremamente cansado e adormeço depois de comer? Isso é verdade quando como qualquer alimento com açúcares simples maiores, principalmente sobremesas. Estou com sono uma hora depois de comer.'},
#  {'candidate_question': 'P: Não importa quão pouco como ou quanto me exercite, não consigo perder peso suficiente. Sigo um plano alimentar equilibrado de 1200 calorias / dia fornecido pelo nutricionista e mantenho um diário alimentar escrito. Entrei para uma academia com um personal trainer e, durante 6 semanas, exercito 1 hora pela manhã antes do trabalho e mais 1-2 horas após o trabalho na maioria dos dias. Fico insultado e frustrado quando a nutricionista diz que não sabe o que fazer porque "o peso deve estar caindo de mim". O médico e o endocrinologista me olham com desconfiança quando exprimo minha frustração e simplesmente digo para continuar a "observar minha dieta e continuar me exercitando". Meus açúcares no sangue diminuíram significativamente, mas ainda não estão onde precisam estar e ainda flutuam descontroladamente às vezes. Isso é horrível .... Desisti de todos os alimentos que "amo" e os exercícios ocuparam a maior parte do meu tempo livre. Não sei quanto tempo posso continuar o sacrifício sem ver os resultados e não sei para onde mais procurar.',
#   'class': 0,
#   'features': {'bert': 0.9059440493583679,
#    'bm25': 26.345260691403464,
#    'cosine': 0.11540884991387164,
#    'muse': 0.29425162076950073,
#    'softcosine': 7.1634616225965395},
#   'qid': 4,
#   'user_question': 'P: Por que fico extremamente cansado e adormeço depois de comer? Isso é verdade quando como qualquer alimento com açúcares simples maiores, principalmente sobremesas. Estou com sono uma hora depois de comer.'},
#  {'candidate_question': 'P: Sou vegetariana e tenho diabetes. Eu não gosto do sabor de ovos ou peixes. Como posso obter proteína suficiente na minha dieta?',
#   'class': 0,
#   'features': {'bert': 0.8863322734832764,
#    'bm25': 1.1717578907812922,
#    'cosine': 0.042755086732844075,
#    'muse': 0.32624080777168274,
#    'softcosine': 3.860303502424878},
#   'qid': 5,
#   'user_question': 'P: Por que fico extremamente cansado e adormeço depois de comer? Isso é verdade quando como qualquer alimento com açúcares simples maiores, principalmente sobremesas. Estou com sono uma hora depois de comer.'},
#  {'candidate_question': 'P: Às vezes, sinto um aumento nos níveis de açúcar no sangue sempre que estou sob muito estresse ou estou doente. Mesmo se eu for rigoroso com minha dieta, há alguma maneira de manter os níveis de açúcar baixos sem ter que tomar insulina? Eles voltarão aos níveis "normais" sem medicação ou ainda precisarei de injeção de insulina?',
#   'class': 0,
#   'features': {'bert': 0.8464531302452087,
#    'bm25': 13.166584115194828,
#    'cosine': 0.24322339646248228,
#    'muse': 0.3886878788471222,
#    'softcosine': 3.2753451778716394},
#   'qid': 1,
#   'user_question': 'P: O que é "diabetes frágil"?'},
#  {'candidate_question': 'P: Quando em uma bomba de insulina, é bom comer o que quiser? Minha enteada adolescente que está nos visitando agora come mais açúcar do que eu já vi alguém comer e quando perguntei a ela sobre sua ingestão de açúcar, e sua resposta foi: "Não importa, eu tenho a bomba".',
#   'class': 0,
#   'features': {'bert': 0.8649542331695557,
#    'bm25': 13.166584115194828,
#    'cosine': 0.26901797717614323,
#    'muse': 0.3446788191795349,
#    'softcosine': 3.759355966776932},
#   'qid': 2,
#   'user_question': 'P: O que é "diabetes frágil"?'},
#  {'candidate_question': 'P: Tenho diabetes tipo 2 e estou tendo problemas para manter o açúcar no sangue da manhã nos níveis desejados. Meus níveis da tarde geralmente estão na faixa normal. Estou acima do peso, mas perdi cerca de 10 kg na esperança de reduzir minha média de açúcar no sangue. No entanto, isso não aconteceu. O que isso poderia significar? Minha doença está progredindo?',
#   'class': 0,
#   'features': {'bert': 0.8546996116638184,
#    'bm25': 2.8337361923391593,
#    'cosine': 0.0473589833123769,
#    'muse': 0.5136479735374451,
#    'softcosine': 3.174413154192713},
#   'qid': 3,
#   'user_question': 'P: O que é "diabetes frágil"?'},
# ...
#   'class': 1,
#   'features': {'bert': 0.8391716480255127,
#    'bm25': 0.0,
#    'cosine': 0.08541025573022394,
#    'muse': 0.08014720678329468,
#    'softcosine': 2.5598207899915835},
#   'qid': 3,
#   'user_question': 'Vocês têm uma lista dos alimentos com quantidade de carboidratos?'},
#  {'candidate_question': 'Por gentileza, alguém me diga se alimentos à base de milho fazem mal, como cuscuz, canjiquinha, angu, etc.',
#   'class': 2,
#   'features': {'bert': 0.8457105159759521,
#    'bm25': 0.0,
#    'cosine': 0.0588604513336236,
#    'muse': 0.41328561305999756,
#    'softcosine': 2.9395198540167833},
#   'qid': 4,
#   'user_question': 'Vocês têm uma lista dos alimentos com quantidade de carboidratos?'},
#  {'candidate_question': 'Qual leite é o ideal? Tomo muito pouco, mas prefiro o integral e o semi desnatado.',
#   'class': 2,
#   'features': {'bert': 0.8141293525695801,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.24902459979057312,
#    'softcosine': 2.442968863072436},
#   'qid': 5,
#   'user_question': 'Vocês têm uma lista dos alimentos com quantidade de carboidratos?'},
#  {'candidate_question': 'Pode comer abacate com adoçante?',
#   'class': 2,
#   'features': {'bert': 0.8367461562156677,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.22262054681777954,
#    'softcosine': 2.09111459101461},
#   'qid': 1,
#   'user_question': 'Quais as fontes de gorduras benéficas? Em quais alimentos eu encontro?'},
#  {'candidate_question': 'Oi. Comer feijoada faz mal para o diabético?',
#   'class': 2,
#   'features': {'bert': 0.8218165636062622,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.39503777027130127,
#    'softcosine': 2.159007233048653},
#   'qid': 2,
#   'user_question': 'Quais as fontes de gorduras benéficas? Em quais alimentos eu encontro?'},
#  {'candidate_question': 'Hoje fiz ovo no molho de açafrão com bastante cheiro verde e cebola. ❤️ Bom almoço, amigos. ❤️',
#   'class': 0,
#   'features': {'bert': 0.7608192563056946,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.16877499222755432,
#    'softcosine': 2.065995194862126},
#   'qid': 3,
#   'user_question': 'Quais as fontes de gorduras benéficas? Em quais alimentos eu encontro?'},
#  {'candidate_question': 'Comi mandioca e quase morri. Hoje comi abacate e banana com pão. Parecia que estava querendo me matar. Sinto muita dor no rim esquerdo. A minha urina está a sair o tempo inteiro.',
#   'class': 1,
#   'features': {'bert': 0.7553681135177612,
#    'bm25': 4.2290055474924815,
#    'cosine': 0.0,
#    'muse': 0.08375567942857742,
#    'softcosine': 2.3609149939811256},
#   'qid': 4,
#   'user_question': 'Quais as fontes de gorduras benéficas? Em quais alimentos eu encontro?'},
#  {'candidate_question': 'Gelatina e chocolate amargo pode comer?',
#   'class': 2,
#   'features': {'bert': 0.8003040552139282,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.2394840568304062,
#    'softcosine': 2.0910329066651636},
#   'qid': 5,
#   'user_question': 'Quais as fontes de gorduras benéficas? Em quais alimentos eu encontro?'},
#  {'candidate_question': 'Cada vez que vou ao médico, escuto a mesma coisa e nada da dor nos pés passar.',
#   'class': 2,
#   'features': {'bert': 0.8847414255142212,
#    'bm25': 0.0,
#    'cosine': 0.13530135502829355,
#    'muse': 0.28328126668930054,
#    'softcosine': 4.378211635812697},
#   'qid': 1,
#   'user_question': 'Eu não consigo nem tomar banho direito. Não tenho força e agilidade nos braços pra tomar banho direito e esfregar os pés, está cada vez mais difícil e não encontrei solução ainda. Me ajudem com opiniões, já tomei Bucliplec e era bom, mas agora não faz efeito, sinto dores nos braços e não consigo andar, ando muito pouco. Eu andava de bicicleta, em dois quarteirões tinha que parar, dava dor nas pernas. E agora dizem que uma academia pode resolver? Acho que não. Só sei que estou me entrevando. O que fazer, gente? Me ajudem.'},
#  {'candidate_question': 'Gente, meu esposo tem um problema que pra gente ainda é um mistério: aparecem bolhas de água sob a pele e, depois, quando ele estoura, viram pequenas feridas. Alguém tem alguma informação sobre isso?',
#   'class': 1,
#   'features': {'bert': 0.8862282633781433,
#    'bm25': 0.0,
#    'cosine': 0.054105297904126014,
#    'muse': 0.2704935073852539,
#    'softcosine': 4.8545375705430045},
#   'qid': 2,
#   'user_question': 'Eu não consigo nem tomar banho direito. Não tenho força e agilidade nos braços pra tomar banho direito e esfregar os pés, está cada vez mais difícil e não encontrei solução ainda. Me ajudem com opiniões, já tomei Bucliplec e era bom, mas agora não faz efeito, sinto dores nos braços e não consigo andar, ando muito pouco. Eu andava de bicicleta, em dois quarteirões tinha que parar, dava dor nas pernas. E agora dizem que uma academia pode resolver? Acho que não. Só sei que estou me entrevando. O que fazer, gente? Me ajudem.'},
#  {'candidate_question': 'O que é bom para controlar neuropatia diabética?',
#   'class': 2,
#   'features': {'bert': 0.7554802894592285,
#    'bm25': 0.0,
#    'cosine': 0.0506253160877055,
#    'muse': 0.18829558789730072,
#    'softcosine': 2.698885189828426},
#   'qid': 3,
#   'user_question': 'Eu não consigo nem tomar banho direito. Não tenho força e agilidade nos braços pra tomar banho direito e esfregar os pés, está cada vez mais difícil e não encontrei solução ainda. Me ajudem com opiniões, já tomei Bucliplec e era bom, mas agora não faz efeito, sinto dores nos braços e não consigo andar, ando muito pouco. Eu andava de bicicleta, em dois quarteirões tinha que parar, dava dor nas pernas. E agora dizem que uma academia pode resolver? Acho que não. Só sei que estou me entrevando. O que fazer, gente? Me ajudem.'},
#  {'candidate_question': 'Alguém sente muita dor de cabeça e enjoo tomando Glifage? Não aguento mais.',
#   'class': 0,
#   'features': {'bert': 0.8673725128173828,
#    'bm25': 0.0,
#    'cosine': 0.11364254229285763,
#    'muse': 0.27575820684432983,
#    'softcosine': 3.0596710832626046},
#   'qid': 4,
#   'user_question': 'Eu não consigo nem tomar banho direito. Não tenho força e agilidade nos braços pra tomar banho direito e esfregar os pés, está cada vez mais difícil e não encontrei solução ainda. Me ajudem com opiniões, já tomei Bucliplec e era bom, mas agora não faz efeito, sinto dores nos braços e não consigo andar, ando muito pouco. Eu andava de bicicleta, em dois quarteirões tinha que parar, dava dor nas pernas. E agora dizem que uma academia pode resolver? Acho que não. Só sei que estou me entrevando. O que fazer, gente? Me ajudem.'},
#  {'candidate_question': 'Bom dia, obrigada por me aceitar. Sou diabética, sofri um acidente de carro no sábado, me machuquei e fui ao médico porque minha mão direita ficou sem sensibilidade e os dedos dormentes. Fizeram raio-x e dizem que não é nada, estou preocupada. Alguém já passou por isso?',
#   'class': 2,
#   'features': {'bert': 0.9031638503074646,
#    'bm25': 0.0,
#    'cosine': 0.08043191041809891,
#    'muse': 0.25708118081092834,
#    'softcosine': 5.559930592173453},
#   'qid': 5,
#   'user_question': 'Eu não consigo nem tomar banho direito. Não tenho força e agilidade nos braços pra tomar banho direito e esfregar os pés, está cada vez mais difícil e não encontrei solução ainda. Me ajudem com opiniões, já tomei Bucliplec e era bom, mas agora não faz efeito, sinto dores nos braços e não consigo andar, ando muito pouco. Eu andava de bicicleta, em dois quarteirões tinha que parar, dava dor nas pernas. E agora dizem que uma academia pode resolver? Acho que não. Só sei que estou me entrevando. O que fazer, gente? Me ajudem.'},
#  {'candidate_question': 'Algum diabético que repõe hormônios da tireoide?',
#   'class': 0,
#   'features': {'bert': 0.8141290545463562,
#    'bm25': 2.9467862891716603,
#    'cosine': 0.09578257631901452,
#    'muse': 0.5208667516708374,
#    'softcosine': 0.8753474860353008},
#   'qid': 1,
#   'user_question': 'Diabético pode doar sangue?'},
#  {'candidate_question': 'Alguém sabe me dizer se distruibuem a insulina NovoRapid no posto ou tem que comprar?',
#   'class': 0,
#   'features': {'bert': 0.7995443344116211,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.3394591212272644,
#    'softcosine': 1.5217022281964192},
#   'qid': 2,
#   'user_question': 'Diabético pode doar sangue?'},
#  {'candidate_question': 'Alguém usa kombucha para controle da diabetes?',
#   'class': 0,
#   'features': {'bert': 0.8414754867553711,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.3865554928779602,
#    'softcosine': 1.5478784288969532},
#   'qid': 3,
#   'user_question': 'Diabético pode doar sangue?'},
#  {'candidate_question': 'Alguém sabe se diabético pode tomar cloreto de magnésio?',
#   'class': 0,
#   'features': {'bert': 0.8289735317230225,
#    'bm25': 5.077237111384232,
#    'cosine': 0.1523088380266489,
#    'muse': 0.5250969529151917,
#    'softcosine': 1.3973893719401893},
#   'qid': 4,
#   'user_question': 'Diabético pode doar sangue?'},
#  {'candidate_question': 'Bom dia, pessoas! Diabéticos podem comer soja?',
#   'class': 0,
#   'features': {'bert': 0.8609756827354431,
#    'bm25': 5.077237111384232,
#    'cosine': 0.17536397408207893,
#    'muse': 0.5656436681747437,
#    'softcosine': 1.669510163147883},
#   'qid': 5,
#   'user_question': 'Diabético pode doar sangue?'},
#  {'candidate_question': 'Pessoal, estou com enjoo de tanto comer ovo. Hoje comi, sem gosto, quase vomitando. É ovo de manhã no café, ovo no almoço, ovo no jantar. Eu quero ir ao mercado, só que estou passando mal direto e tenho medo de morrer na rua. Fora outra coisa, tive febre alta, dor de garganta, fraqueza profunda e essas pernas que formigam, mesmo a diabetes estando controlada.',
#   'class': 0,
#   'features': {'bert': 0.8194756507873535,
#    'bm25': 4.599517222130281,
#    'cosine': 0.031835908116540516,
#    'muse': 0.22268229722976685,
#    'softcosine': 3.093949675023237},
#   'qid': 1,
#   'user_question': 'Qual o melhor creme para as pernas do diabético? Goicoechea ou Diabetex? Para pele e circulação.'},
#  {'candidate_question': 'Boa noite. Qual trigo vocês usam? E farinha para empanar? Por favor.',
#   'class': 0,
#   'features': {'bert': 0.8336608409881592,
#    'bm25': 0.0,
#    'cosine': 0.061653488302995746,
#    'muse': 0.21732529997825623,
#    'softcosine': 3.0376396650025206},
#   'qid': 2,
#   'user_question': 'Qual o melhor creme para as pernas do diabético? Goicoechea ou Diabetex? Para pele e circulação.'},
#  {'candidate_question': 'Almocei saladinha, 1 colher de feijão, peixe à milanesa feito na farinha de arroz, e por último comi suflê de brócolis feito com um pouco de trigo. Fiquei ruim. Porque será?',
#   'class': 0,
#   'features': {'bert': 0.8195335268974304,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.019687414169311523,
#    'softcosine': 3.03028711716806},
#   'qid': 3,
#   'user_question': 'Qual o melhor creme para as pernas do diabético? Goicoechea ou Diabetex? Para pele e circulação.'},
#  {'candidate_question': 'Gente, podemos comer banana verde frita?',
#   'class': 0,
#   'features': {'bert': 0.8002711534500122,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.08803814649581909,
#    'softcosine': 2.324478050121993},
#   'qid': 4,
#   'user_question': 'Qual o melhor creme para as pernas do diabético? Goicoechea ou Diabetex? Para pele e circulação.'},
#  {'candidate_question': 'Verdade que não podemos comer batata doce?',
#   'class': 0,
#   'features': {'bert': 0.7983496189117432,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.16346658766269684,
#    'softcosine': 2.3245145046550686},
#   'qid': 5,
#   'user_question': 'Qual o melhor creme para as pernas do diabético? Goicoechea ou Diabetex? Para pele e circulação.'},
#  {'candidate_question': 'Quando glicose está normal, precisa tomar os remédios?',
#   'class': 0,
#   'features': {'bert': 0.8053023815155029,
#    'bm25': 0.0,
#    'cosine': 0.15595402995210786,
#    'muse': 0.1495351642370224,
#    'softcosine': 1.7804453960970692},
#   'qid': 1,
#   'user_question': 'Algum remédio para cólica menstrual?'},
#  {'candidate_question': 'Comprei hoje o aparelho que mede a glicose. Medi duas horas depois do almoço e deu 135. Está bom?',
#   'class': 0,
#   'features': {'bert': 0.7212858200073242,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.029036371037364006,
#    'softcosine': 1.355068684888955},
#   'qid': 2,
#   'user_question': 'Algum remédio para cólica menstrual?'},
#  {'candidate_question': 'Boa tarde. Tomo remédio para dormir e como maracujá e não consigo dormir cedo. O que fazer?',
#   'class': 0,
#   'features': {'bert': 0.8032724857330322,
#    'bm25': 0.0,
#    'cosine': 0.0881142585755296,
#    'muse': 0.24477016925811768,
#    'softcosine': 1.4195258525599517},
#   'qid': 3,
#   'user_question': 'Algum remédio para cólica menstrual?'},
#  {'candidate_question': 'Minha sogra está com diabetes 230 em jejum. Está tomando 2 tipos de comprimidos, mas mesmo assim não abaixa. E o médico só vai ter em setembro, será que é muito perigoso esperar até lá? Muito obrigado.',
#   'class': 0,
#   'features': {'bert': 0.7820097804069519,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.11004264652729034,
#    'softcosine': 2.1931573538141955},
#   'qid': 4,
#   'user_question': 'Algum remédio para cólica menstrual?'},
#  {'candidate_question': 'Animam, gente? Uma salada de brócolis com camarão 😋',
#   'class': 0,
#   'features': {'bert': 0.6935495138168335,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': -0.004115048795938492,
#    'softcosine': 0.9955098725867509},
#   'qid': 5,
#   'user_question': 'Algum remédio para cólica menstrual?'},
#  {'candidate_question': 'Bom dia. Eu me acidentei, sou diabético tipo 1. O que posso passar em cima do ferimento? Me ajudem.',
#   'class': 0,
#   'features': {'bert': 0.8820041418075562,
#    'bm25': 0.0,
#    'cosine': 0.07443536124095829,
#    'muse': 0.2501705288887024,
#    'softcosine': 3.3733258134515522},
#   'qid': 1,
#   'user_question': 'Eu vi algo relacionado ao vinagre de maçã. Ele é bom para quem tem ácido úrico, é isso? Boa noite.'},
#  {'candidate_question': 'Bom dia, povo abençoado. Eu estou pasma: acordei com a glicose em 108, comi uma banana prata e fui caminhar. Quando cheguei, a glicose estava 151. Como pode isso?',
#   'class': 0,
#   'features': {'bert': 0.8603472709655762,
#    'bm25': 0.0,
#    'cosine': 0.055760924747462734,
#    'muse': 0.1467718631029129,
#    'softcosine': 3.6769290303107947},
#   'qid': 2,
#   'user_question': 'Eu vi algo relacionado ao vinagre de maçã. Ele é bom para quem tem ácido úrico, é isso? Boa noite.'},
#  {'candidate_question': 'Há algumas semanas venho trazendo minha glicemia em jejum até 120. Ontem, eu jantei bem tarde e, hoje, minha glicemia amanheceu em 227. Comi normalmente, será que é por que eu jantei muito tarde?',
#   'class': 0,
#   'features': {'bert': 0.8566262722015381,
#    'bm25': 0.0,
#    'cosine': 0.0,
#    'muse': 0.20274218916893005,
#    'softcosine': 2.7955873392244954},
#   'qid': 3,
#   'user_question': 'Eu vi algo relacionado ao vinagre de maçã. Ele é bom para quem tem ácido úrico, é isso? Boa noite.'},
#  {'candidate_question': 'Alô, grupo! Bom dia. Podem me informar um leite que nós podemos tomar?',
#   'class': 0,
#   'features': {'bert': 0.8696423172950745,
#    'bm25': 0.0,
#    'cosine': 0.043753291830923156,
#    'muse': 0.19430889189243317,
#    'softcosine': 3.425292633602305},
#   'qid': 4,
#   'user_question': 'Eu vi algo relacionado ao vinagre de maçã. Ele é bom para quem tem ácido úrico, é isso? Boa noite.'},
#  {'candidate_question': 'Bom dia. Me digam a verdade: tem muita gente postando o resultado da glicemia em jejum entre 88 a 106, vocês conseguem manter assim até o outro dia?',
#   'class': 0,
#   'features': {'bert': 0.8794302940368652,
#    'bm25': 0.0,
#    'cosine': 0.027158541338406908,
#    'muse': 0.16871310770511627,
#    'softcosine': 3.8383138105002867},
#   'qid': 5,
#   'user_question': 'Eu vi algo relacionado ao vinagre de maçã. Ele é bom para quem tem ácido úrico, é isso? Boa noite.'},
#  {'candidate_question': 'Boa tarde, podemos usar farinha de grão de bico?',
#   'class': 2,
#   'features': {'bert': 0.8065770864486694,
#    'bm25': 0.0,
#    'cosine': 0.0332366982165776,
#    'muse': 0.48434609174728394,
#    'softcosine': 1.8075348778728375},
#   'qid': 1,
#   'user_question': 'Gente, esquece a banana, vamos falar do alho poró. Alguém sabe se podemos comer?'}]

# %% [markdown]
# # Keep Pre-training BERT in WhatsApp Messages

# %%
import json
import os

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

import torch
from transformers import AutoTokenizer  # Or BertTokenizer
from transformers import AutoModelForPreTraining, AutoModelForMaskedLM  # Or BertForPreTraining for loading pretraining heads
from transformers import AutoModel  # or BertModel, for BERT without pretraining heads

# %% [markdown]
# Load Corpus

# %%
CORPORA_PATH = [
        'QA/adalberto/qa_pt.json',
        'QA/diabetes_action/qa_pt.json',
        'QA/diabetesbr/qa_pt.json',
        'QA/eatingwell/qa_pt.json',
        'QA/medicine/qa_pt.json'
    ]

texts = []
for path in CORPORA_PATH:
    corpus = json.load(open(path))
    for qa in corpus:
      texts.append(qa['question'])
      texts.append(qa['answer'])

# %%
import codecs
import re

def is_start(line):
    if re.match(r'^\d+/\d+/\d+', line):
        return True
    return False

messages, msg = [], []
for fname in [w for w in os.listdir('QA/whatsapp') if not w.startswith('.')]:
    print(fname)
    with codecs.open(os.path.join('QA/whatsapp', fname), "r", "utf-8-sig") as f:
        for line in f.read().split('\n')[1:]:
            if is_start(line):
                if len(msg) > 0:
                    messages.append({
                        'author': author,
                        'date': date,
                        'msg': '\n'.join(msg)
                    })
                msg = []
                try:
                    date, rest = line.split(' - ')
                    author, paragraph = rest.split(':')
                    msg.append(paragraph)
                except:
                    pass
            else:
                msg.append(line)

texts.extend([w['msg'].strip() for w in messages if w['msg'].strip() != '<Media omitted>' and w['msg'].strip() != '<Arquivo de mídia oculto>'])
print('CORPUS SIZE:', len(texts))

with open('corpus.txt', 'w') as f:
  f.write('\n'.join(texts))
# Out:
# Sosdiabetes20201001.txt
# Diabeticados3.txt
# PessoinhasDoBem20200911.txt
# Diabeticados320201001.txt
# ContraDiabetes20201109.txt
# SosDiabetes20201112.txt
# PessoinhasdoBem20200924.txt
# PessoinhasDoBem20201001.txt
# SosDiabetes20200924.txt
# PessoinhasDoBem20201212.txt
# Diabeticados320200924.txt
# ContraDiabetes20201001.txt
# Diabeticados320200911.txt
# Diabeticados320201212.txt
# Sosdiabetes20200911.txt
# CORPUS SIZE: 17071

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
tokenizer = AutoTokenizer.from_pretrained('neuralmind/bert-large-portuguese-cased', do_lower_case=False)
model = AutoModelForMaskedLM.from_pretrained('neuralmind/bert-large-portuguese-cased')
# model = model.to(device)
# Out:
# Some weights of the model checkpoint at neuralmind/bert-large-portuguese-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from transformers import LineByLineTextDataset

dataset = LineByLineTextDataset(
    tokenizer=tokenizer,    
    file_path="./corpus.txt",
    block_size=128,
)
# Out:
# /usr/local/lib/python3.6/dist-packages/transformers/data/datasets/language_modeling.py:114: FutureWarning: This dataset will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/master/examples/language-modeling/run_mlm.py
#   FutureWarning,

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=True, mlm_probability=0.15
)

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir="./diabert",
    overwrite_output_dir=True,
    num_train_epochs=1,
    per_gpu_train_batch_size=16,
    save_steps=10_000,
    save_total_limit=2,
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset,
    prediction_loss_only=True,
)
# Out:
# /usr/local/lib/python3.6/dist-packages/transformers/trainer.py:281: FutureWarning: Passing `prediction_loss_only` as a keyword argument is deprecated and won't be possible in a future version. Use `args.prediction_loss_only` instead. Setting `args.prediction_loss_only=True
#   FutureWarning,

# %%
trainer.train()
# Out:
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='1671' max='1671' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1671/1671 28:15, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.505189</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.375761</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.369500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1671, training_loss=0.4133181340818559)

# %%
trainer.save_model("./diabert")

# %%
from models.bert import BERTQA

model = BERTQA(corpora_path, pretrained='diabert')

MAP = []
for q1 in testset:
  y_real, y_pred = [], []
  for row in testset[q1]:
    q2 = row['question']
    label = row['label']
    score = model.score_pair(q1, q2)
    y_real.append(1 if label in ['S', 'R'] else 0)
    y_pred.append(score)
    if len(list(set(y_real))) > 1:
      MAP.append(average_precision_score(y_real, y_pred))
print("BERT Finetunned Score:", round(np.mean(MAP), 2))
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at diabert and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERT Finetunned Score: 0.81

# %%
from transformers import pipeline

fill_mask = pipeline(
    "fill-mask",
    model="./diabert",
    tokenizer=tokenizer
)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at ./diabert and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
fill_mask("Retinopatia [MASK]")
# Out:
# [{'score': 0.2595193684101105,
#   'sequence': '[CLS] Retinopatia : [SEP]',
#   'token': 131,
#   'token_str': ':'},
#  {'score': 0.1802317500114441,
#   'sequence': '[CLS] Retinopatia? [SEP]',
#   'token': 136,
#   'token_str': '?'},
#  {'score': 0.1395806521177292,
#   'sequence': '[CLS] Retinopatia. [SEP]',
#   'token': 119,
#   'token_str': '.'},
#  {'score': 0.056920938193798065,
#   'sequence': '[CLS] Retinopatia crônica [SEP]',
#   'token': 16785,
#   'token_str': 'crônica'},
#  {'score': 0.055065009742975235,
#   'sequence': '[CLS] Retinopatias [SEP]',
#   'token': 22281,
#   'token_str': '##s'}]
